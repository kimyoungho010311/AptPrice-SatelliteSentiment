# %%
import pandas as pd
import os

# %%
folder_path = '../csv'
file_list = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# %%
dfs = []

for file_name in file_list:
    # 파일명에서 자치구 이름을 추출한 후
    gu_name = file_name.replace('_news.csv', '')
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path, encoding='utf=8-sig')
    # 자치구 컬럼에 자치구 이름을 추가함
    df['자치구'] = gu_name

    # 날짜 컬럼을 datetime으로 변경함
    df['날짜'] = pd.to_datetime(df['날짜'], format='%Y.%m.%d', errors='coerce')
    dfs.append(df)

merged_df = pd.concat(dfs, axis=0, ignore_index=True)

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4390 entries, 0 to 4389
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      4390 non-null   object
#  1   날짜      4389 non-null   datetime64[ns]
#  2   본문      4390 non-null   object
#  3   URL     4390 non-null   object
#  4   자치구     4390 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 171.6+ KB

# %%
merged_df['자치구'].unique()
# Out:
# array(['중랑구', '양천구', '광진구', '서초구', '송파구', '강동구', '성동구', '은평구', '서대문구',
#        '노원구', '마포구', '강남구', '성북구', '강북구', '영등포구', '도봉구', '동대문구', '용산구',
#        '금천구', '중구', '종로구', '구로구', '동작구', '강서구', '관악구'], dtype=object)

# %%
merged_df.head()
# Out:
#                              제목         날짜  \
# 0      사가정역 먹자골목  ‘사가정51길’로 새단장 2022-03-28
# 1      서울 상봉 역세권 247가구 주상복합 짓는다 2022-02-16
# 2     LH, 양원 신혼희망타운 당첨자발표 오류 물의 2019-08-06
# 3   중랑구, 가을에 찾아가는  ‘책 읽는 공원’ 운영 2016-11-10
# 4  ‘중랑 면목패션(봉제) 특정개발진흥지구’ 본격 추진 2016-04-07
#
#                                                   본문  \
# 0  다양한 문화공간 구비한 먹자골목으로 변신\n사가정51길 특화거리 조감도(야간)\n[...
# 1  [파이낸셜뉴스] 서울 상봉역 역세권 일대에 247가구를 포함한 주상복합 건물이 들어...
# 2  LH가 서울 양원지구 신혼희망타운 당첨자 발표에서 오류를 일으켜 물의를 빚었다. /...
# 3  12일 오전 11시부터 오후 4시까지, 능산공원에서 가을의 정취를 느낄 수 있는‘책...
# 4  ▲‘중랑 면목패션(봉제) 특정개발진흥지구’ 위치도 /사진=서울시\n서울시는 지난 6...
#
#                                                URL  자치구
# 0  https://n.news.naver.com/article/016/0001969159  중랑구
# 1  https://n.news.naver.com/article/014/0004788865  중랑구
# 2  https://n.news.naver.com/article/417/0000435883  중랑구
# 3  https://n.news.naver.com/article/277/0003866883  중랑구
# 4  https://n.news.naver.com/article/014/0003630962  중랑구

# %%
len(merged_df[merged_df['날짜'] >= pd.to_datetime('2023-01-01')])
# Out:
# 1638

# %%
gang = pd.read_csv("../csv/강남구_news.csv")

# %%
gang['날짜'] = pd.to_datetime(df['날짜'], format='%Y.%m.%d', errors='coerce')

# %%
gang[gang['날짜'] >= pd.to_datetime('2023-01-01')]
# Out:
#                                                  제목         날짜  \
# 1             2채 중 1채 증여였던 '강남 아파트'… 한 달 새 225건→13건 2024-09-27
